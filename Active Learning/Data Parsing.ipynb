# %% [markdown]
# ### Installing the required Modules

# %%
# Importing the require modules
import numpy as np

import os
import pickle 
import blosc

import re
from pprint import pprint

from openbabel import pybel
from openbabel import openbabel as ob
from xtb.interface import Calculator, Param
from xtb.libxtb import VERBOSITY_MUTED

error_files = []

# %% [markdown]
# ## Helper function filter to extract all the bond lengths, angles and dihedrals from a molecule

# %%
def filterAtom(atom: str) -> str:
    '''Removes any number from the string e.g. C3 becomes C'''
    pattern_order = r'[0-9]'
    return re.sub(pattern_order, '', atom)

def atomType(mol, atomIdx) -> str:
    '''get the atomic type given an atom index'''
    return mol.OBMol.GetAtom(atomIdx).GetType()

# %%
def getBondOrders_Charges(mol):
    
    coords = []
    for atom in mol.atoms:
        coords.append([atom.coords[0], atom.coords[1], atom.coords[2]])
    
    # xtb-python expects them in Bohr
    atom_coords = np.array(coords) / 0.52917721092
    atomic_nums = np.array([a.atomicnum for a in mol.atoms])
    
    # Creating the calculator
    calc = Calculator(Param.GFN2xTB, atomic_nums, atom_coords)
    calc.set_verbosity(VERBOSITY_MUTED)
    res = calc.singlepoint()
    
    # Get the partial charges
    charges = res.get_charges()
    
    # Get the bond order matrix
    bond_orders = res.get_bond_orders()
    
    '''
    print("Charges:")
    for i, charge in enumerate(charges):
        print("%d\t%f" % (i+1, charge))
        
    print("Bond orders (matrix):")
    for i, row in enumerate(bond_orders):
        for j, bond_order in enumerate(row):
            if j > i and bond_order > 0.1:
                print("%d \t %d \t %f" % (i+1, j+1, bond_order))
    '''
    
    return (charges, bond_orders)

# %%
def getBonds(mol, charge, bond_order) -> dict:
    '''Iterate through all the bonds in a molecule'''
    
    bonds = {}
    
    for bond in ob.OBMolBondIter(mol.OBMol):
        index1 = bond.GetBeginAtomIdx()
        index2 = bond.GetEndAtomIdx()
        begin = filterAtom(atomType(mol, index1))
        end = filterAtom(atomType(mol, index2))
        bond_length = round(bond.GetLength(),4)
        bondOrder = bond_order[index1-1][index2-1]
        
        # Swap them for lexographic order
        if (end < begin):
            begin, end = end, begin
        
        #Appending to the dictionary of list
        if (f"{begin} - {end} , {bond_order}" in bonds.keys()):
            bonds[f"{begin} - {end} , {round(bondOrder,1)}"].append((bond_length, charge[index1-1], charge[index2-1], 
                                                             round(bondOrder,2)))
        else:
            bonds[f"{begin} - {end} , {round(bondOrder,1)}"]=[(bond_length, charge[index1-1], charge[index2-1], 
                                                             round(bondOrder,2))]
        
    return bonds

# %%
def getAngles(mol, charge) -> dict:
    '''Iterate through all the bond angles in a molecule'''
    
    angles = {}
    
    for angle in ob.OBMolAngleIter(mol.OBMol):
        index1 = mol.OBMol.GetAtom(angle[0] + 1) 
        index3 = mol.OBMol.GetAtom(angle[2] + 1)
        
        a = angle[0] + 1
        b = mol.OBMol.GetAtom(angle[1] + 1)
        c = angle[2] + 1
        bond_angle = round(b.GetAngle(a, c), 3)

        aType = filterAtom(atomType(mol, a))
        bType = filterAtom(b.GetType())
        cType = filterAtom(atomType(mol, c))
        
        # Swap them for lexographic order
        if (cType < aType):
            aType, cType = cType, aType
            
        #Appedning to the dictonary of lists if the angle b/t the elements already existse
        if(f"{aType} - {bType} - {cType}" in angles.keys()):
            angles[f"{aType} - {bType} - {cType}"].append((bond_angle, charge[index1.GetIdx()-1], charge[b.GetIdx()-1], charge[index3.GetIdx()-1]))
        else:
            angles[f"{aType} - {bType} - {cType}"] = [(bond_angle, charge[index1.GetIdx()-1], charge[b.GetIdx()-1], charge[index3.GetIdx()-1])]                                                                                      
                                                                                                     
    return angles

# %%
def getTorsions(mol) -> dict:
    '''Iterate through all the torsions in a molecule'''
    
    torsions = {}
    
    for torsion in ob.OBMolTorsionIter(mol.OBMol):
        a = torsion[0] + 1
        b = torsion[1] + 1
        c = torsion[2] + 1
        d = torsion[3] + 1
        torsion_angle = mol.OBMol.GetTorsion(a, b, c, d)

        aType = filterAtom(atomType(mol, a))
        bType = filterAtom(atomType(mol, b))
        cType = filterAtom(atomType(mol, c))
        dType = filterAtom(atomType(mol, d))

        # Switch if not in lexographic order
        if(dType < aType):
            aType, dType = dType, aType
            
        #Appedning to the dictonary of lists if the torsion angle b/t the elements already existse
        if(f"{aType} - {bType} - {cType} -{dType}" in torsions.keys()):
            torsions[f"{aType} - {bType} - {cType} -{dType}"].append(round(torsion_angle, 3))
        
        # Checking for palindromic sequence
        elif(f"{dType} - {cType} - {bType} -{aType}" in torsions.keys()):
            torsions[f"{dType} - {cType} - {bType} -{aType}"].append(round(torsion_angle, 3))
            
        else:
            torsions[f"{aType} - {bType} - {cType} -{dType}"] = [round(torsion_angle, 3)]
    
    return torsions

# %% [markdown]
# ### Wrapping all the helper functions into a main function

# %%
def analyze_molecular_data(file: str) -> (dict, dict, dict):
    '''Fetches the bond lengths, angles and dihedrals from a given file'''
    
    # Load the File
    extension=file.split('.')[-1]
    try:
        mol = next(pybel.readfile(extension, file))
    except:
        error_files.append(file)
        return ({},{},{})
    
    # Get Bond Order and partial charges on atoms
    charge, bond_order = getBondOrders_Charges(mol)
    
    # Get bond lengths
    bond_lengths = getBonds(mol, charge, bond_order)
    
    # Get bond angles
    #bond_angles = getAngles(mol, charge)
    
    # Get torsions
    #dihedrals = getTorsions(mol)

    return (bond_lengths, bond_angles, dihedrals)


def mergeDictionaries(dict1 : dict, dict2: dict):
    '''Merges two Python dictionary by combining elements for a common key
    The function merges dict2 into dict 1'''
    for key, value in dict2.items():
        if key in dict1:
            dict1[key].extend(value)
        else:
            dict1[key] = value

# %% [markdown]
# ### Testing the above functions on a sample molecule

# %%
# Example usage
xyz_file = '21395061/cod-crest/W/WKGCLMYDEAXJHN-UHFFFAOYSA-N.xyz'
mol = next(pybel.readfile('xyz', xyz_file))
#charge, bond_order = getBondOrders_Charges(mol)
#pprint(getBonds(mol))
#getAngles(mol, charge, bond_order)
#pprint(getTorsions(mol))


molecular_data = analyze_molecular_data(xyz_file)
molecular_data
# Out:
# ({'C - H , 1.0': [(1.0878, -0.10378644121202354, 0.03503875690424905, 0.99)],
#   'C - C , 1.0': [(1.5238, -0.0538759726750265, -0.10378644121202354, 1.02)],
#   'Car - H , 1.0': [(1.0787,
#     -0.07378025401053186,
#     0.028046603974882154,
#     0.97)],
#   'C - O , 1.0': [(1.4109, -0.2725605392681584, 0.08552330034790456, 0.97)],
#   'Car - Car , 1.3': [(1.402,
#     -0.034884437064210544,
#     -0.07378025401053186,
#     1.33)],
#    (118.624, -0.04392668891392972, -0.006318110742138991, 0.04633223409595779),
#    (121.323, -0.04392668891392972, -0.034884437064210544, 0.04633223409595779),
#    (118.563, -0.03488430725622948, -0.07378148041046168, 0.03061058582202533),
#    (120.35, -0.03488430725622948, -0.04392716028684564, 0.03061058582202533),
#    (121.323, -0.04392716028684564, -0.03488430725622948, 0.046332178891116675),
#    (118.624,
#     -0.04392716028684564,
#     -0.006318018580995247,
#     0.046332178891116675),
#    (120.35, -0.034884437064210544, -0.04392668891392972, 0.03061067559374586),
#    (118.563, -0.034884437064210544, -0.07378025401053186, 0.03061067559374586),
#    (121.127, -0.07378025401053186, 0.1373627899491629, 0.028046603974882154),
#    (118.521,
#     -0.07378025401053186,
#     -0.034884437064210544,
#     0.028046603974882154)],
#   'C - C - C': [(111.557,
#     -0.06537992102945255,
#     0.08552415188015444,
#     -0.061425321142258724),
#    (112.053,
#     -0.061425321142258724,
#     -0.06537992102945255,
#     -0.053875656833527824),
#    (111.71,
#     -0.053875656833527824,
#     -0.061425321142258724,
#     -0.10378630636174666),
#    (111.554, -0.06537943670923957, 0.08552330034790456, -0.06142603768719997),
#    (112.048, -0.06142603768719997, -0.06537943670923957, -0.0538759726750265),
#    (111.706, -0.0538759726750265, -0.06142603768719997, -0.10378644121202354)],
#   'Car - Car - O': [(115.19,
#     0.1373627899491629,
#     -0.006318018580995247,
#     -0.2725605392681584)]},
#  {'H - C - C -H': [-61.147,
#    -178.881,
#    58.925,
#    -58.81,
#    178.989,
#    61.255,
#    62.525,
#    -179.946,
#    179.932,
#    -62.539,
#    -61.726,
#    179.653,
#    -179.256,
#    62.122,
#    62.032,
#    178.996,
#    -178.547,
#    -61.583,
#    61.583,
#    -178.995,
#    178.547,
#    -62.031,
#    -62.12,
#    -179.652,
#    179.257,
#    61.725,
#    62.537,
#    179.946,
#    -179.933,
#    -62.524,
#    -61.255,
#    58.808,
#    178.88,
#    -178.99,
#    -58.927,
#    61.145],
#   'C - C - C -H': [59.988,
#    -179.941,
#    -59.876,
#    -58.713,
#    58.694,
#    -58.775,
#    58.754,
#    58.948,
#    59.511,
#    -59.11,
#    -58.582,
#    -59.483,
#    59.938,
#    -59.937,
#    59.484,
#    59.111,
#    58.583,
#    -58.949,
#    -59.512,
#    -58.755,
#    58.775,
#    -58.695,
#    58.713,
#    59.875,
#    179.939,
#    -59.99],
#   'C - C - C -C': [179.987, -179.815, 179.815, -179.987],
#   'C - C - C -O': [-179.787, 179.788],
#   'H - C - C -O': [-58.271, 58.692, -58.692, 58.273],
#   'Car - C - O -H': [59.91, -59.824],
#   'C - C - O -Car': [-179.962],
#   'H - Car - Car -H': [-0.008, 0.008, -0.008, 0.008],
#   'Car - Car - Car -H': [179.993,
#    179.984,
#    -179.999,
#    -179.989,
#    -179.993,
#    -179.996,
#    -0.004,
#    0.004,
#    179.996,
#    179.989,
#    179.992,
#    -180.0,
#    -179.993,
#    -179.984],
#   'Car - Car - Car -Car': [-0.015,
#    0.009,
#    0.01,
#    0.002,
#    179.995,
#    0.0,
#    179.993,
#    -0.007,
#    -179.999,
#    -179.999,
#    0.008,
#    -179.994,
#    -0.001,
#    -179.996,
#    -0.003,
#    -0.011,
#    -0.008,
#    0.016],
#   'H - Car - Car -O': [0.018, -0.017],
#   'Car - Car - Car -O': [-179.974, 179.986, -0.021, 0.02, -179.987, 179.974],
#   'C - O - Car -Car': [-0.22, 179.796],
#   'C - Car - O -Car': [-179.792, 0.224],
#   'Car - O - C -H': [59.818, -59.916],
#   'C - O - C -Car': [179.956]})

# %% [markdown]
# ## Extracting Molecular Data from all the files

# %%
#Collecting data from the Molecular Dataset

bond_lengths = {}
bond_angles = {}
dihedrals = {}

ext = ('.xyz',)
count = 0

for root, dirs, files in os.walk('21395061/cod-crest/'):
    for file in files:
        extension=os.path.splitext(file)[1]
        count +=1
        if(extension not in ext): continue
            
        filename = os.path.join(root,file)
        length, angle, torsion = analyze_molecular_data(filename)
        
        mergeDictionaries(bond_lengths, length)
        #mergeDictionaries(bond_angles, angle)
        #mergeDictionaries(dihedrals, torsion)
# Out:
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is SCF done        -59.433677868596          0.000316298731)
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is SCF done        -79.377053843214          0.000924825445)
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is SCF done        -86.034286802623          0.000854184241)
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is SCF done        -58.758444780557          0.000328546459)
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is SCF done       -111.085364902439          0.000603406375)
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is SCF done       -103.528980684869          0.000489942664)
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is SCF done        -91.618324994391          0.000451592379)
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is SCF done        -47.904507960930          0.000624225537)
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is SCF done       -123.291770173335          0.004257724296)
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is SCF done        -67.933800642714          0.000022658712)
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is SCF done        -54.741411146963          0.000023864018)
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is SCF done        -65.928512167706          0.000041000417)
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is SCF done        -63.816337773019          0.000764854539)
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is SCF done        -33.076018943498          0.000057625620)
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is SCF done        -90.249582360331          0.000724290671)
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is SCF done        -45.486054680693          0.000080930899)
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is SCF done        -72.809047248895          0.000646908694)
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is SCF done        -53.519204655577          0.000518082814)
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is SCF done        -38.788342784347          0.000028646160)
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is SCF done        -62.445795400250          0.000569675671)
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is SCF done        -56.453897088243          0.000536675389)
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is SCF done        -67.053588802969          0.000504266049)
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is SCF done        -31.795490219675          0.000177146926)
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is SCF done        -70.572101771602          0.000652205869)
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is SCF done        -79.181162503194          0.000348938329)
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is SCF done        -66.110439142096          0.000732379118)
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is SCF done        -54.912656354422          0.000076902699)
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is SCF done       -102.554895262280          0.000691391819)
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is SCF done        -30.633978009276          0.000363577331)
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is SCF done        -46.645103455011          0.000548255983)
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is SCF done        -80.869706573568          0.000856931429)
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is SCF done        -76.458169883262          0.000837888185)
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is SCF done        -28.699874426751          0.000488286646)
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is SCF done        -56.287248309815          0.000501621727)
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is SCF done        -93.403993224875          0.000616043537)
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is SCF done        -53.398803274734          0.000687708352)
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is SCF done        -77.437456252631          0.000459156128)
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is SCF done        -65.137391857482          0.000832278420)
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is SCF done        -44.108593635585          0.000464924613)
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is SCF done        -94.340217728248          0.000410361877)
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is SCF done        -65.485149618314          0.000041819052)
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is SCF done        -84.893951507837          0.000432179138)
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is SCF done        -43.338442248229          0.000158257975)
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is SCF done       -161.206963397959          0.000759112675)
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is SCF done        -29.282164042213          0.000830019973)
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is SCF done        -61.188387478083          0.000949836438)
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is SCF done        -80.702722942629          0.000600218865)
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is SCF done        -64.851303561732          0.000559924050)
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is SCF done        -85.290092181789          0.000421393099)
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is SCF done       -152.761086171118          0.000344759362)
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is SCF done        -60.945352391280          0.000583603326)
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is SCF done        -37.590018990476          0.000972848829)
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is SCF done        -71.191046839522          0.000789231278)
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is SCF done        -61.392704114707          0.000338725248)
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is SCF done        -89.282037192888          0.000408318027)
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is SCF done       -259.328846682880          0.000516343091)
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is SCF done        -81.254784699611          0.000019484152)
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is SCF done        -97.062157889126          0.000829411592)
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is SCF done       -122.734853677508          0.000444564161)
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is SCF done        -71.747622877593          0.000033442023)
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is SCF done        -70.363854254171          0.000338592000)
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is SCF done        -48.543274369593          0.000759665970)
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is SCF done        -91.974245507643          0.000627503022)
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is SCF done        -64.437666279541          0.000635365300)
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is SCF done        -72.202094208329          0.000605905551)
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is SCF done        -70.313180584904          0.000692778458)
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is SCF done        -97.630808821160          0.000605762097)
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is SCF done        -75.245290122994          0.000919179709)
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is SCF done        -97.699317231667          0.002251855330)
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is SCF done       -177.794998053748          0.000699424702)
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is SCF done        -47.472189865713          0.000973731879)
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is SCF done        -44.101070494530          0.000430785135)
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is SCF done        

#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is SCF done        -42.569067300332          0.000578575269)
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is -92.20864719)
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is -169.14440852)
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is SCF done       -230.316556882211          0.000362193910)
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is SCF done        -45.914113277521          0.000036781905)
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is -171.75161387)
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is -54.06921735)
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is -72.34308014)
# ---------------------------------------------------------------------------
# XTBException                              Traceback (most recent call last)
# Cell In[12], line 17
#      14 if(extension not in ext): continue
#      16 filename = os.path.join(root,file)
# ---> 17 length, angle, torsion = analyze_molecular_data(filename)
#      19 mergeDictionaries(bond_lengths, length)
#      20 #mergeDictionaries(bond_angles, angle)
#      21 #mergeDictionaries(dihedrals, torsion)
#
# Cell In[11], line 13, in analyze_molecular_data(file)
#      10     return ({},{},{})
#      12 # Get Bond Order and partial charges on atoms
# ---> 13 charge, bond_order = getBondOrders_Charges(mol)
#      15 # Get bond lengths
#      16 bond_lengths = getBonds(mol, charge, bond_order)
#
# Cell In[3], line 14, in getBondOrders_Charges(mol)
#      12 calc = Calculator(Param.GFN2xTB, atomic_nums, atom_coords)
#      13 calc.set_verbosity(VERBOSITY_MUTED)
# ---> 14 res = calc.singlepoint()
#      16 # Get the partial charges
#      17 charges = res.get_charges()
#
# File ~/miniconda3/envs/GSOC/lib/python3.11/site-packages/xtb/interface.py:826, in Calculator.singlepoint(self, res, copy)
#     821 _lib.xtb_singlepoint(
#     822     self._env, self._mol, self._calc, _res._res,
#     823 )
#     825 if self.check() != 0:
# --> 826     raise XTBException(self.get_error("Single point calculation failed"))
#     828 return _res
#
# XTBException: Single point calculation failed:
# -2- xtb_calculator_singlepoint: Electronic structure method terminated
# -1- scf: Self consistent charge iterator did not converge

# %% [markdown]
# ### Running the corrupt xyz files with corresponding sdf files and writing the bond length, angle, torsion data as pickle object

# %%
#Trying with sfd files for the corrupted xyz files

for file in error_files:
    filename = os.path.splitext(file)[0] + '.sdf'
    length, angle, torsion = analyze_molecular_data(filename)
    mergeDictionaries(bond_lengths, length)
    #mergeDictionaries(bond_angles, angle)
    #mergeDictionaries(dihedrals, torsion)

# %%
def MolecularDataWriter_compress():
    
    pickled_bond_lengths = pickle.dump(bond_lengths)
    compressed_bond_lengths = blosc.compress(pickled_bond_lengths)
    
    with open('cod-crest_bond_lengths.dat', 'wb') as f:
        f.write(compressed_bond_lengths)
        
    pickled_bond_angles = pickle.dump(bond_angles)
    compressed_bond_angles = blosc.compress(pickled_bond_angles)
        
    with open('cod-crest_bond_angles.dat', 'wb') as f:
        f.write(compressed_bond_angles)
        
    pickled_torsions = pickle.dump(torsion)
    compressed_dihedrals = blosc.compress(pickled_torsions)
        
    with open('cod-crest_torsions.dat', 'wb') as f:
        f.write(compressed_dihedrals)

# %%
def MolecularDataWriter_pickle():
    
    for key in bond_lengths.keys():
        bond_lengths[key] = np.array(bond_lengths[key])
        
    for key in bond_angles.keys():
        bond_angles[key] = np.array(bond_angles[key])
        
    for key in dihedrals.keys():
        dihedrals[key] = np.array(dihedrals[key])
    
    with open('cod-crest_bond_lengths_.pkl', 'wb') as f:
        pickle.dump(bond_lengths, f)
        
#     with open('cod-crest_bond_angles.pkl', 'wb') as f:
#         pickle.dump(bond_angles, f)
        
#     with open('cod-crest_torsions.pkl', 'wb') as f:
#         pickle.dump(dihedrals, f)

# %%
MolecularDataWriter_pickle()
